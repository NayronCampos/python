# %%
import pandas as pd

tabela = pd.read_csv("Dados.csv", sep = ";")

tabela = tabela.drop(columns="RESPONSÁVEL")

display(tabela)
# Out:
#                    SECRETARIA CONTRATO MÊS REFERÊNCIA MÊS FATURAMENTO  \
# 0   FHEMIG - João Penido (JF)  9442480         dez/25          fev/26
# 1   FHEMIG - João Penido (JF)  9442480         jan/26          fev/26
# 2  DER - GOVERNADOR VALADARES                  jan/26          fev/26
#
#   DATA EMISSÃO NOTA FISCAL  NF     VALOR BRUTO  DATA RECEBIMENTO  \
# 0               04/02/2026  22   R$ 298.276,56        02/03/2026
# 1               20/02/2026  76   R$ 228.368,59        02/03/2026
# 2               09/02/2026  28    R$ 77.299,89        02/03/2026
#
#    VALOR RECEBIDO    TEMPO RECEBIMENTO   ...   VALOR BRUTO .1           ISS   \
# 0   R$ 269.293,73                    26  ...   R$ 298.276,56    R$ 8.948,30
# 1   R$ 206.166,84                    10  ...   R$ 228.368,59    R$ 6.851,06
# 2    R$ 72.507,30                    21  ...    R$ 77.299,89    R$ 3.864,99
#
#            IRRF              CP   CSLL   PIS/COFINS   TOTAL IMPOSTOS   \
# ...

# %%
display(tabela.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SECRETARIA                3 non-null      str
#  1   CONTRATO                  3 non-null      str
#  2   MÊS REFERÊNCIA            3 non-null      str
#  3   MÊS FATURAMENTO           3 non-null      str
#  4   DATA EMISSÃO NOTA FISCAL  3 non-null      str
#  5   NF                        3 non-null      int64
#  6    VALOR BRUTO              3 non-null      str
#  7   DATA RECEBIMENTO          3 non-null      str
#  8    VALOR RECEBIDO           3 non-null      str
#  9    TEMPO RECEBIMENTO        3 non-null      int64
#  10   VALOR DESCONTO           3 non-null      str
#  11   PERCENTUAL DESCONTO      3 non-null      str
#  12  Unnamed: 13               0 non-null      float64
#  13   VALOR BRUTO .1           3 non-null      str
# ...
